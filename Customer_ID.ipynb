# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df3 = pd.read_csv("C:/Users/user/OneDrive/Desktop/Career/Data Glacier VI/VC-1/DataSets/Customer_ID.csv")
df4 = pd.read_csv("C:/Users/user/OneDrive/Desktop/Career/Data Glacier VI/VC-1/DataSets/Transaction_ID.csv")

# %%
df3.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %%
df4.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %%
df3.describe()
# Out:
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000

# %%
df3.shape
# Out:
# (49171, 4)

# %%
df3.isnull().sum()
# Out:
# Customer ID           0
# Gender                0
# Age                   0
# Income (USD/Month)    0
# dtype: int64

# %%
df3['Income (USD/Month)'].mean()
# Out:
# 15015.631856175389

# %%
inner = pd.merge(df3, df4, on='Customer ID')

# %%
inner
# Out:
#         Customer ID  Gender  Age  Income (USD/Month)  Transaction ID  \
# 0             29290    Male   28               10813        10000011
# 1             29290    Male   28               10813        10351127
# 2             29290    Male   28               10813        10412921
# 3             27703    Male   27                9237        10000012
# 4             27703    Male   27                9237        10320494
# ...             ...     ...  ...                 ...             ...
# 440093        12490    Male   33               18713        10439799
# 440094        14971    Male   30               15346        10439820
# 440095        41414    Male   38                3960        10439838
# 440096        41677    Male   23               19454        10439840
# 440097        39761  Female   32               10128        10439846
#
#        Payment_Mode
# 0              Card
# 1              Cash
# 2              Card
# 3              Card
# 4              Card
# ...

# %%
# Customer Segmentation

# %%
sns.set_style('darkgrid')

# %%
sns.histplot(x = 'Age', data=df3, binwidth=10, binrange=(24, 74), hue='Gender', element='poly');

# %%
sns.set_style('dark')

# %%
sns.lineplot(y= 'Income (USD/Month)', x= 'Age', hue='Gender', data=inner, estimator='mean');

# %%
sns.lineplot(y='Income (USD/Month)', x='Age', hue='Payment_Mode', data=inner, estimator='mean');

# %%
sns.histplot(x='Age', data=inner, binwidth=10, binrange=(24, 74), hue='Gender', element='poly');

# %%
sns.set(style='white', palette='muted', color_codes=True)
fig, axs = plt.subplots(1, 2, figsize=(12, 3))
sns.despine(left=True)
axs[0] = sns.histplot(inner['Age'], bins=20, ax=axs[0])
axs[1] = sns.histplot(inner['Income (USD/Month)'], bins=20, ax=axs[1], color='g')
fig.suptitle('Numerical Feature Distribution')
plt.setp(axs, yticks=[])
plt.tight_layout()
plt.show()

# %%
# Create new age category
bins = [18, 24, 50, 70]
labels = ['Young', 'Adult', 'Senior']
inner['Age_Range'] = pd.cut(inner['Age'], bins=bins, labels=labels, right=False)
inner.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)  Transaction ID Payment_Mode  \
# 0        29290   Male   28               10813        10000011         Card
# 1        29290   Male   28               10813        10351127         Cash
# 2        29290   Male   28               10813        10412921         Card
# 3        27703   Male   27                9237        10000012         Card
# 4        27703   Male   27                9237        10320494         Card
#
#   Age_Range
# 0     Adult
# 1     Adult
# 2     Adult
# 3     Adult
# 4     Adult

# %%
import seaborn as sns

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-04999d3d1045> in <module>
# ----> 1 inner.shape
#
# AttributeError: 'function' object has no attribute 'shape'

# %%
inner.shape
# Out:
# (440098, 7)
